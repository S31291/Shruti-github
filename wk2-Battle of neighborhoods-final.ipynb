# %% [markdown]
# 1.Introduction: A customer wants to open a restaurant in Bangalore. He is looking for a potential neigborhood in Bangalore having many companies with good employee size, to open his restaurant.

# %% [markdown]
# 2.Data Section-Preparing the three datasets

# %% [markdown]
# Importing Dataset1.xlsx from local computer and converitng it to a pandas dataframe

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_3fa636d9b3f646ac8f3bb5de175890e6 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='r1O87ZSHhNgI9W4mn1UaavErqBTxdY1bjcrlqevvEnqb',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_3fa636d9b3f646ac8f3bb5de175890e6.get_object(Bucket='businessproblemibmapplieddatascie-donotdelete-pr-dtdt3j8tjafjfu',Key='Dataset1.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_0 = pd.read_excel(body)
df_data_0.head()
# Out:
#   Country  Pincode                 Area Bangalore-Division  Latitude  \
# 0      IN   560001     Bangalore G.P.O.    Bangalore North   12.9914
# 1      IN   560001     Legislators Home    Bangalore North   12.9914
# 2      IN   560001        Vasanthanagar    Bangalore North   12.9914
# 3      IN   560001  Mahatma Gandhi Road    Bangalore North   12.9914
# 4      IN   560001       Vidhana Soudha    Bangalore North   12.9914
#
#    Longitude
# 0    77.5944
# 1    77.5944
# 2    77.5944
# 3    77.5944
# 4    77.5944

# %%
dataset1=df_data_0
dataset1
# Out:
#     Country  Pincode                            Area Bangalore-Division  \
# 0        IN   560001                Bangalore G.P.O.    Bangalore North
# 1        IN   560001                Legislators Home    Bangalore North
# 2        IN   560001                   Vasanthanagar    Bangalore North
# 3        IN   560001             Mahatma Gandhi Road    Bangalore North
# 4        IN   560001                  Vidhana Soudha    Bangalore North
# 5        IN   560001           Rajbhavan (Bangalore)    Bangalore North
# 6        IN   560001                       HighCourt    Bangalore North
# 7        IN   560001                     Cubban Road    Bangalore North
# 8        IN   560001                Bangalore Bazaar    Bangalore North
# 9        IN   560001               CMM Court Complex    Bangalore North
# 10       IN   560001             Dr. Ambedkar Veedhi    Bangalore North
# 11       IN   560002                  Bangalore City    Bangalore North
# ...

# %% [markdown]
# Importing Dataset2.xlsx from local computer.

# %%
body = client_3fa636d9b3f646ac8f3bb5de175890e6.get_object(Bucket='businessproblemibmapplieddatascie-donotdelete-pr-dtdt3j8tjafjfu',Key='Dataset2.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_excel(body)
df_data_2.head()
# Out:
#    Pincode  E.no 1-50  E.no 51-100  E.no 101-250  E.no 251-500  E.no 501-1000  \
# 0   560001        157           90            91            54             22
# 1   560002         47           23            13             6              0
# 2   560003         54           22            16             5              2
# 3   560004         53           28            27            10              0
# 4   560005         37           14             6             0              1
#
#    E.no 1001-2500  E.no 2501-5000  E.no 5001 & above
# 0              14               8                  7
# 1               2               0                  1
# 2               1               0                  0
# 3               2               1                  1
# 4               0               1                  1

# %%
dataset2=df_data_2
dataset2
# Out:
#     Pincode  E.no 1-50  E.no 51-100  E.no 101-250  E.no 251-500  \
# 0    560001        157           90            91            54
# 1    560002         47           23            13             6
# 2    560003         54           22            16             5
# 3    560004         53           28            27            10
# 4    560005         37           14             6             0
# 5    560006          1            1             1             1
# 6    560007          0            0             0             0
# 7    560008        101           57            38            16
# 8    560009         30           13            14             2
# 9    560010         64           31            19             6
# 10   560011         62           38            22             7
# 11   560012          3            0             0             2
# 12   560013          7            5             7             1
# 13   560014          2            0             0             0
# ...

# %% [markdown]
# Preparing Dataset3 - Dataset1 followed by addition of Foursquare data.

# %% [markdown]
# i. Removing columns designated as 'Country','Pincode' and 'Bangalore-Division' from Dataset1.

# %%
df=dataset1.drop(['Country','Pincode','Bangalore-Division'], axis=1)

# %%
df
# Out:
#                                Area  Latitude  Longitude
# 0                  Bangalore G.P.O.   12.9914    77.5944
# 1                  Legislators Home   12.9914    77.5944
# 2                     Vasanthanagar   12.9914    77.5944
# 3               Mahatma Gandhi Road   12.9914    77.5944
# 4                    Vidhana Soudha   12.9914    77.5944
# 5             Rajbhavan (Bangalore)   12.9914    77.5944
# 6                         HighCourt   12.9914    77.5944
# 7                       Cubban Road   12.9914    77.5944
# 8                  Bangalore Bazaar   12.9914    77.5944
# 9                 CMM Court Complex   12.9914    77.5944
# 10              Dr. Ambedkar Veedhi   12.9914    77.5944
# 11                   Bangalore City   12.9719    77.5937
# 12   Bangalore Corporation Building   12.9719    77.5937
# 13       Sri Jayachamarajendra Road   12.9719    77.5937
# 14                Palace Guttahalli   13.0097    77.5648
# ...

# %% [markdown]
# ii.Grouping data by Longitude and Latitude and joining the areas.

# %%
long_lat_data=df.groupby(['Longitude','Latitude'],sort=False).agg(', '.join)
long_lat_data.reset_index(inplace=True)
long_lat_data
# Out:
#     Longitude  Latitude                                               Area
# 0     77.5944   12.9914  Bangalore G.P.O., Legislators Home, Vasanthana...
# 1     77.5937   12.9719  Bangalore City, Bangalore Corporation Building...
# 2     77.5648   13.0097  Palace Guttahalli, Malleswaram, Swimming Pool ...
# 3     76.0303   13.5207                 Pampamahakavi Road, Thyagarajnagar
# 4     74.4891   14.0998                                            Mavalli
# 5     77.5714   12.9417                                       Basavanagudi
# 6     76.9627   13.2029  Fraser Town, J.C.Nagar, Training Command IAF, ...
# 7     77.5491   12.9847  Rajajinagar, Industrial Estate (Bangalore), Ra...
# 8     76.2752   15.8266  Jayangar III Block, Madhavan Park, Science Ins...
# 9     77.5474   13.0448                                          Jalahalli
# 10    73.7291   21.4504                                    Vimanapura, NAL
# ...

# %% [markdown]
# iii. Seting up Foursqaure credentials

# %%
CLIENT_ID = 'NJO5CSY5OPUDPDP51UFVB0TOIKJW51G21KUKGU3QIZLTEE5I' # your Foursquare ID
CLIENT_SECRET = 'M50DCNP1YIGF30YIPMKLKQ5SHLBLGHPKKDCBXPDSC1M3LPPX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: NJO5CSY5OPUDPDP51UFVB0TOIKJW51G21KUKGU3QIZLTEE5I
# CLIENT_SECRET:M50DCNP1YIGF30YIPMKLKQ5SHLBLGHPKKDCBXPDSC1M3LPPX

# %% [markdown]
# iv. Trial-Generating data for pair of longitude and latitude using Foursqaure data.

# %%
radius = 1000
search_query1='Food'

# %%
longitude =long_lat_data.loc[11,'Longitude']
latitude =long_lat_data.loc[11,'Latitude']
LIMIT=2000
longitude
# Out:
# 77.5789

# %%
url='https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query1, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NJO5CSY5OPUDPDP51UFVB0TOIKJW51G21KUKGU3QIZLTEE5I&client_secret=M50DCNP1YIGF30YIPMKLKQ5SHLBLGHPKKDCBXPDSC1M3LPPX&ll=12.9879,77.5789&v=20180605&query=Food&radius=1000&limit=2000'

# %%
import json
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f15ec2faf2b4b31375ab395'},
#  'response': {'venues': [{'id': '4c15e70e7f7f2d7f4725e368',
#     'name': 'Food Court',
#     'location': {'address': 'Mantri Square, Malleshwaram',
#      'crossStreet': '1, Sampige Rd',
#      'lat': 12.991646212171805,
#      'lng': 77.57061710566572,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.991646212171805,
#        'lng': 77.57061710566572}],
#      'distance': 990,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Mantri Square, Malleshwaram (1, Sampige Rd)',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
# ...

# %%
# assign relevant part of JSON to venues
V1= results['response']['venues']
dataframe = json_normalize(V1)
V1=dataframe['name']
V1
# Out:
# 0                         Food Court
# 1                         food shack
# 2                         Food Point
# 3                    Sagar food mall
# 4             General Food Additives
# 5                     forgotten food
# 6     Commissionerate of Food Safety
# 7           Vegbynature- food courts
# 8      Golden Landmark Food,Banglore
# 9                  Healthy Food Tech
# 10           Palette, The food court
# 11                        Kaati Zone
# Name: name, dtype: object

# %%
V1.count()
# Out:
# 12

# %% [markdown]
# v.Running a for loop to check all the Food Outlets within 2000m(2km) of all longitudes and latitudes.

# %%
data=[]
for i in range (68):
    radius = 2000
    search_query='Food'
    longitude =long_lat_data.loc[i,'Longitude']
    latitude =long_lat_data.loc[i,'Latitude']
    LIMIT=5000
    url='https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()
    V1= results['response']['venues']
    dataframe = json_normalize(V1)
    if 'name' in dataframe:
         V1=dataframe['name'].count()
         f1=(V1,longitude,latitude)
         data.append(f1)
         print(V1,longitude,latitude)
    else:
         f1=(0, longitude,latitude)
         data.append(f1)
         print (0,longitude,latitude)
# Out:
# 31 77.5944 12.9914
# 49 77.5937 12.9719
# 47 77.5648 13.0097
# 0 76.0303 13.5207
# 0 74.4891 14.0998
# 35 77.5714 12.9417
# 0 76.9627 13.2029
# 37 77.5491 12.9847
# 0 76.2752 15.8266
# 9 77.5474 13.0448
# 0 73.7291 21.4504
# 42 77.5789 12.9879
# 44 77.5625 12.9879
# 0 77.4484 13.11
# 32 77.5489 12.975
# 48 77.6025 12.9634
# 31 77.5952 12.9506
# 0 76.8024 13.7952
# 50 77.6079 12.944
# 50 77.6153 12.938
# 50 77.6227 12.932
# 0 77.492 12.6859
# 50 77.5885 12.9278
# 28 77.6487 13.0158
# 20 77.6226 13.036
# 37 77.6044 12.9985
# 20 77.7164 12.9944
# 21 77.6869 12.9923
# 0 76.5761 10.8368
# 40 77.5609 13.0323
# 8 77.481 12.9121
# 0 77.7432 12.769
# 0 78.0988 12.3477
# 10 77.5963 13.1013
# 1 78.6014 11.5941
# 22 77.7473 12.9716
# 3 77.6279 12.8706
# 23 77.626 12.8949
# 50 77.6209 12.924
# 19 77.6299 12.8931
# 50 77.5798 12.9229
# 50 77.6391 12.9617
# 9 77.5113 12.9801
# 48 77.5978 12.8939
# 50 77.6001 12.9106
# 21 77.5709 12.902
# 17 77.5617 12.9057
# 19 77.5663 12.9038
# 37 77.5806 13.0104
# ...

# %%
data
# Out:
# [(31, 77.5944, 12.9914),
#  (49, 77.5937, 12.9719),
#  (47, 77.5648, 13.0097),
#  (0, 76.0303, 13.5207),
#  (0, 74.4891, 14.0998),
#  (35, 77.5714, 12.9417),
#  (0, 76.9627, 13.2029),
#  (37, 77.5491, 12.9847),
#  (0, 76.2752, 15.8266),
#  (9, 77.5474, 13.0448),
#  (0, 73.7291, 21.4504),
#  (42, 77.5789, 12.9879),
#  (44, 77.5625, 12.9879),
#  (0, 77.4484, 13.11),
#  (32, 77.5489, 12.975),
#  (48, 77.6025, 12.9634),
#  (31, 77.5952, 12.9506),
#  (0, 76.8024, 13.7952),
#  (50, 77.6079, 12.944),
#  (50, 77.6153, 12.938),
#  (50, 77.6227, 12.932),
#  (0, 77.492, 12.6859),
#  (50, 77.5885, 12.9278),
#  (28, 77.6487, 13.0158),
#  (20, 77.6226, 13.036),
#  (37, 77.6044, 12.9985),
#  (20, 77.7164, 12.9944),
#  (21, 77.6869, 12.9923),
#  (0, 76.5761, 10.8368),
#  (40, 77.5609, 13.0323),
#  (8, 77.481, 12.9121),
#  (0, 77.7432, 12.769),
#  (0, 78.0988, 12.3477),
#  (10, 77.5963, 13.1013),
#  (1, 78.6014, 11.5941),
#  (22, 77.7473, 12.9716),
#  (3, 77.6279, 12.8706),
#  (23, 77.626, 12.8949),
# ...

# %% [markdown]
# vi.Converting the data into a pandas dataframe designating it as 'dataset3'.

# %%
dataset3=pd.DataFrame(data=data)
dataset3
# Out:
#      0        1        2
# 0   31  77.5944  12.9914
# 1   49  77.5937  12.9719
# 2   47  77.5648  13.0097
# 3    0  76.0303  13.5207
# 4    0  74.4891  14.0998
# 5   35  77.5714  12.9417
# 6    0  76.9627  13.2029
# 7   37  77.5491  12.9847
# 8    0  76.2752  15.8266
# 9    9  77.5474  13.0448
# 10   0  73.7291  21.4504
# 11  42  77.5789  12.9879
# 12  44  77.5625  12.9879
# 13   0  77.4484  13.1100
# 14  32  77.5489  12.9750
# 15  48  77.6025  12.9634
# 16  31  77.5952  12.9506
# 17   0  76.8024  13.7952
# 18  50  77.6079  12.9440
# 19  50  77.6153  12.9380
# 20  50  77.6227  12.9320
# 21   0  77.4920  12.6859
# 22  50  77.5885  12.9278
# 23  28  77.6487  13.0158
# 24  20  77.6226  13.0360
# 25  37  77.6044  12.9985
# 26  20  77.7164  12.9944
# 27  21  77.6869  12.9923
# 28   0  76.5761  10.8368
# 29  40  77.5609  13.0323
# ..  ..      ...      ...
# 38  50  77.6209  12.9240
# 39  19  77.6299  12.8931
# 40  50  77.5798  12.9229
# 41  50  77.6391  12.9617
# 42   9  77.5113  12.9801
# ...

# %% [markdown]
# Naming the columns of the generated dataframe.

# %%
dataset3.columns=['Number of Food Outlets','longitude','latitude']
dataset3
# Out:
#     Number of Food Outlets  longitude  latitude
# 0                       31    77.5944   12.9914
# 1                       49    77.5937   12.9719
# 2                       47    77.5648   13.0097
# 3                        0    76.0303   13.5207
# 4                        0    74.4891   14.0998
# 5                       35    77.5714   12.9417
# 6                        0    76.9627   13.2029
# 7                       37    77.5491   12.9847
# 8                        0    76.2752   15.8266
# 9                        9    77.5474   13.0448
# 10                       0    73.7291   21.4504
# 11                      42    77.5789   12.9879
# 12                      44    77.5625   12.9879
# 13                       0    77.4484   13.1100
# 14                      32    77.5489   12.9750
# 15                      48    77.6025   12.9634
# 16                      31    77.5952   12.9506
# 17                       0    76.8024   13.7952
# 18                      50    77.6079   12.9440
# ...

# %% [markdown]
# Printing all datasets.

# %% [markdown]
# Printing all three datasets

# %% [markdown]
# Dataset1: Consists of data of all areas/neighborhoods in bangalore with their corresponding pincodes and longitudes and latitude.This dataset gives informations regarding the neigborhoods in bangalore.

# %%
dataset1
# Out:
#     Country  Pincode                            Area Bangalore-Division  \
# 0        IN   560001                Bangalore G.P.O.    Bangalore North
# 1        IN   560001                Legislators Home    Bangalore North
# 2        IN   560001                   Vasanthanagar    Bangalore North
# 3        IN   560001             Mahatma Gandhi Road    Bangalore North
# 4        IN   560001                  Vidhana Soudha    Bangalore North
# 5        IN   560001           Rajbhavan (Bangalore)    Bangalore North
# 6        IN   560001                       HighCourt    Bangalore North
# 7        IN   560001                     Cubban Road    Bangalore North
# 8        IN   560001                Bangalore Bazaar    Bangalore North
# 9        IN   560001               CMM Court Complex    Bangalore North
# 10       IN   560001             Dr. Ambedkar Veedhi    Bangalore North
# 11       IN   560002                  Bangalore City    Bangalore North
# ...

# %% [markdown]
# Dataset2: Consists of data :number of the companies with various employee sizes ,for ll pincodes in Bangalore. This dataset helps identify the neighborhoods in bangalore(with help of pincode) best suited for opening a restaurant.Potential neighborhoods will be the ones with high number of employees.

# %%
dataset2
# Out:
#     Pincode  E.no 1-50  E.no 51-100  E.no 101-250  E.no 251-500  \
# 0    560001        157           90            91            54
# 1    560002         47           23            13             6
# 2    560003         54           22            16             5
# 3    560004         53           28            27            10
# 4    560005         37           14             6             0
# 5    560006          1            1             1             1
# 6    560007          0            0             0             0
# 7    560008        101           57            38            16
# 8    560009         30           13            14             2
# 9    560010         64           31            19             6
# 10   560011         62           38            22             7
# 11   560012          3            0             0             2
# 12   560013          7            5             7             1
# 13   560014          2            0             0             0
# ...

# %% [markdown]
# Dataset 3:Consists of all longitudes and latitudes (same for many pincodes), along with the number of food outlets within 2000m (2km). This data will help select a potential areas/neighborhood to open a restaurant.Potential area/neighbourhoods wll be ones with low number of food outlets.

# %%
dataset3
# Out:
#     Number of Food Outlets  longitude  latitude
# 0                       31    77.5944   12.9914
# 1                       49    77.5937   12.9719
# 2                       47    77.5648   13.0097
# 3                        0    76.0303   13.5207
# 4                        0    74.4891   14.0998
# 5                       35    77.5714   12.9417
# 6                        0    76.9627   13.2029
# 7                       37    77.5491   12.9847
# 8                        0    76.2752   15.8266
# 9                        9    77.5474   13.0448
# 10                       0    73.7291   21.4504
# 11                      42    77.5789   12.9879
# 12                      44    77.5625   12.9879
# 13                       0    77.4484   13.1100
# 14                      32    77.5489   12.9750
# 15                      48    77.6025   12.9634
# 16                      31    77.5952   12.9506
# 17                       0    76.8024   13.7952
# 18                      50    77.6079   12.9440
# ...

# %% [markdown]
# Note: All datasets will have the same number of rows and columns during execution of clustering.
#     They have different number of rows and columns now, as they have many repeated data in them.

# %% [markdown]
# 3.Methodology and Results

# %% [markdown]
# 3.1 Integration of three datasets

# %%
body = client_3fa636d9b3f646ac8f3bb5de175890e6.get_object(Bucket='businessproblemibmapplieddatascie-donotdelete-pr-dtdt3j8tjafjfu',Key='Dataset2.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_excel(body)
df_data_2.head()
# Out:
#    Pincode  E.no 1-50  E.no 51-100  E.no 101-250  E.no 251-500  E.no 501-1000  \
# 0   560001        157           90            91            54             22
# 1   560002         47           23            13             6              0
# 2   560003         54           22            16             5              2
# 3   560004         53           28            27            10              0
# 4   560005         37           14             6             0              1
#
#    E.no 1001-2500  E.no 2501-5000  E.no 5001 & above
# 0              14               8                  7
# 1               2               0                  1
# 2               1               0                  0
# 3               2               1                  1
# 4               0               1                  1

# %% [markdown]
# 3.1.1 Preparing dataconcat12grouped:merging dataset1 and dataset2 and then obtaining a dataset with the number of companies by Longitude,Latitude and Pincode.

# %%
dataset1['Longitude']=dataset1['Longitude'].astype(str)
dataset1['Latitude']=dataset1['Latitude'].astype(str)
dataset1
# Out:
#     Country  Pincode                            Area Bangalore-Division  \
# 0        IN   560001                Bangalore G.P.O.    Bangalore North
# 1        IN   560001                Legislators Home    Bangalore North
# 2        IN   560001                   Vasanthanagar    Bangalore North
# 3        IN   560001             Mahatma Gandhi Road    Bangalore North
# 4        IN   560001                  Vidhana Soudha    Bangalore North
# 5        IN   560001           Rajbhavan (Bangalore)    Bangalore North
# 6        IN   560001                       HighCourt    Bangalore North
# 7        IN   560001                     Cubban Road    Bangalore North
# 8        IN   560001                Bangalore Bazaar    Bangalore North
# 9        IN   560001               CMM Court Complex    Bangalore North
# 10       IN   560001             Dr. Ambedkar Veedhi    Bangalore North
# 11       IN   560002                  Bangalore City    Bangalore North
# ...

# %%
dataf=dataset1.groupby(['Pincode'], sort=False).agg(','.join)
dataf1=dataf.drop(['Country','Bangalore-Division'], axis=1)
dataf1
# Out:
#                                                       Area  \
# Pincode
# 560001   Bangalore G.P.O.,Legislators Home,Vasanthanaga...
# 560002   Bangalore City,Bangalore Corporation Building,...
# 560003   Palace Guttahalli,Malleswaram,Swimming Pool Ex...
# 560004   Pampamahakavi Road,Thyagarajnagar,Mavalli,Basa...
# 560005                                         Fraser Town
# 560006                      J.C.Nagar,Training Command IAF
# 560007                            Agram,Air Force Hospital
# 560008                        Hulsur Bazaar,H.A.L II Stage
# 560009              K. G. Road,Bangalore Dist Offices Bldg
# 560010   Rajajinagar,Industrial Estate (Bangalore),Raja...
# 560011                    Jayangar III Block,Madhavan Park
# 560012                                   Science Institute
# 560013                                           Jalahalli
# 560014                                      Jalahalli East
# 560015                                      Jalahalli West
# ...

# %%
dataf2=dataf1.applymap(lambda x: x if ',' not in str(x) else ','.join(sorted(set(y.strip() for y in(x.split(','))))))
dataf3=dataf2.reset_index(drop=False, inplace=False)
dataf3
# Out:
#     Pincode                                               Area  \
# 0    560001  Bangalore Bazaar,Bangalore G.P.O.,CMM Court Co...
# 1    560002  Bangalore City,Bangalore Corporation Building,...
# 2    560003  Malleswaram,Palace Guttahalli,Swimming Pool Ex...
# 3    560004  Basavanagudi,Mavalli,Pampamahakavi Road,Thyaga...
# 4    560005                                        Fraser Town
# 5    560006                     J.C.Nagar,Training Command IAF
# 6    560007                           Agram,Air Force Hospital
# 7    560008                       H.A.L II Stage,Hulsur Bazaar
# 8    560009             Bangalore Dist Offices Bldg,K. G. Road
# 9    560010  Industrial Estate (Bangalore),Rajajinagar,Raja...
# 10   560011                   Jayangar III Block,Madhavan Park
# 11   560012                                  Science Institute
# 12   560013                                          Jalahalli
# 13   560014                                     Jalahalli East
# ...

# %%
df_data_2=dataset2.drop(['Pincode'], axis=1)
df_data_2
# Out:
#     E.no 1-50  E.no 51-100  E.no 101-250  E.no 251-500  E.no 501-1000  \
# 0         157           90            91            54             22
# 1          47           23            13             6              0
# 2          54           22            16             5              2
# 3          53           28            27            10              0
# 4          37           14             6             0              1
# 5           1            1             1             1              0
# 6           0            0             0             0              0
# 7         101           57            38            16              2
# 8          30           13            14             2              1
# 9          64           31            19             6              6
# 10         62           38            22             7              4
# 11          3            0             0             2              0
# ...

# %% [markdown]
# attaching dataset2 (designated as df_data_2 in the previous step) to dataf3 (dataset1 - grouped by Pincode)

# %%
dataconcat12=pd.concat([dataf3,df_data_2], axis=1)
dataconcat12
# Out:
#     Pincode                                               Area  \
# 0    560001  Bangalore Bazaar,Bangalore G.P.O.,CMM Court Co...
# 1    560002  Bangalore City,Bangalore Corporation Building,...
# 2    560003  Malleswaram,Palace Guttahalli,Swimming Pool Ex...
# 3    560004  Basavanagudi,Mavalli,Pampamahakavi Road,Thyaga...
# 4    560005                                        Fraser Town
# 5    560006                     J.C.Nagar,Training Command IAF
# 6    560007                           Agram,Air Force Hospital
# 7    560008                       H.A.L II Stage,Hulsur Bazaar
# 8    560009             Bangalore Dist Offices Bldg,K. G. Road
# 9    560010  Industrial Estate (Bangalore),Rajajinagar,Raja...
# 10   560011                   Jayangar III Block,Madhavan Park
# 11   560012                                  Science Institute
# 12   560013                                          Jalahalli
# 13   560014                                     Jalahalli East
# ...

# %%
dataconcat12['Pincode']=dataconcat12['Pincode'].astype(str)
dataconcat12['Area']=dataconcat12['Area'].astype(str)
dataconcat12
# Out:
#    Pincode                                               Area  \
# 0   560001  Bangalore Bazaar,Bangalore G.P.O.,CMM Court Co...
# 1   560002  Bangalore City,Bangalore Corporation Building,...
# 2   560003  Malleswaram,Palace Guttahalli,Swimming Pool Ex...
# 3   560004  Basavanagudi,Mavalli,Pampamahakavi Road,Thyaga...
# 4   560005                                        Fraser Town
# 5   560006                     J.C.Nagar,Training Command IAF
# 6   560007                           Agram,Air Force Hospital
# 7   560008                       H.A.L II Stage,Hulsur Bazaar
# 8   560009             Bangalore Dist Offices Bldg,K. G. Road
# 9   560010  Industrial Estate (Bangalore),Rajajinagar,Raja...
# 10  560011                   Jayangar III Block,Madhavan Park
# 11  560012                                  Science Institute
# 12  560013                                          Jalahalli
# 13  560014                                     Jalahalli East
# ...

# %%
dataconcat12=dataconcat12.drop(['Area','Pincode'],axis=1)
dataconcat12
# Out:
#                    Latitude                Longitude  E.no 1-50  E.no 51-100  \
# 0                   12.9914                  77.5944        157           90
# 1                   12.9719                  77.5937         47           23
# 2                   13.0097                  77.5648         54           22
# 3   12.9417,13.5207,14.0998  74.4891,76.0303,77.5714         53           28
# 4                   13.2029                  76.9627         37           14
# 5                   13.2029                  76.9627          1            1
# 6                   13.2029                  76.9627          0            0
# 7                   13.2029                  76.9627        101           57
# 8                   13.2029                  76.9627         30           13
# 9                   12.9847                  77.5491         64           31
# 10                  15.8266                  76.2752         62           38
# ...

# %%
dataconcat12grouped=dataconcat12.groupby(['Longitude','Latitude']).agg(sum)
dataconcat12grouped=dataconcat12grouped.reset_index(drop=False,inplace=False)
dataconcat12grouped
# Out:
#                          Longitude                        Latitude  E.no 1-50  \
# 0                          73.7291                         21.4504         36
# 1          74.4891,76.0303,77.5714         12.9417,13.5207,14.0998         53
# 2                          76.2752                         15.8266        112
# 3                          76.5761                         10.8368         16
# 4                          76.8024                         13.7952         28
# 5                          76.9627                         13.2029        169
# 6                          77.0942                         13.1791        104
# 7                          77.4484                           13.11         67
# 8                           77.481                         12.9121          6
# 9                           77.492                         12.6859         88
# 10                         77.5053                         12.7717         16
# ...

# %%
dataconcat12grouped=dataconcat12grouped.applymap(lambda x: x if ',' not in str(x) else ','.join(sorted(set(y.strip() for y in(x.split(','))))))
dataconcat12grouped
# Out:
#                          Longitude                        Latitude  E.no 1-50  \
# 0                          73.7291                         21.4504         36
# 1          74.4891,76.0303,77.5714         12.9417,13.5207,14.0998         53
# 2                          76.2752                         15.8266        112
# 3                          76.5761                         10.8368         16
# 4                          76.8024                         13.7952         28
# 5                          76.9627                         13.2029        169
# 6                          77.0942                         13.1791        104
# 7                          77.4484                           13.11         67
# 8                           77.481                         12.9121          6
# 9                           77.492                         12.6859         88
# 10                         77.5053                         12.7717         16
# ...

# %% [markdown]
# 3.1.2 Preparing dataconcat14:merging dataset1 and dataset3 and then adding the number of food outlets by Longitude,Latitude and Pincode.

# %%
datasetfirst=dataset1
datasetfirst
# Out:
#     Country  Pincode                            Area Bangalore-Division  \
# 0        IN   560001                Bangalore G.P.O.    Bangalore North
# 1        IN   560001                Legislators Home    Bangalore North
# 2        IN   560001                   Vasanthanagar    Bangalore North
# 3        IN   560001             Mahatma Gandhi Road    Bangalore North
# 4        IN   560001                  Vidhana Soudha    Bangalore North
# 5        IN   560001           Rajbhavan (Bangalore)    Bangalore North
# 6        IN   560001                       HighCourt    Bangalore North
# 7        IN   560001                     Cubban Road    Bangalore North
# 8        IN   560001                Bangalore Bazaar    Bangalore North
# 9        IN   560001               CMM Court Complex    Bangalore North
# 10       IN   560001             Dr. Ambedkar Veedhi    Bangalore North
# 11       IN   560002                  Bangalore City    Bangalore North
# ...

# %%
datasetfirst['Longitude'].dtype
# Out:
# dtype('O')

# %%
datasetfirst['Longitude']=datasetfirst['Longitude'].astype(float)
datasetfirst['Latitude']=datasetfirst['Latitude'].astype(float)
datasetfirst['Pincode']=datasetfirst['Pincode'].astype(str)

# %%
datasetsecond=datasetfirst.groupby(['Longitude','Latitude'],sort=False).agg(','.join)
datasetsecond=datasetsecond.drop(['Country','Area','Bangalore-Division'], axis=1)
datasetsecond=datasetsecond.applymap(lambda x: x if ',' not in str(x) else ','.join(sorted(set(y.strip() for y in(x.split(','))))))
datasetsecond=datasetsecond.reset_index(drop=False,inplace=False)
datasetsecond
# Out:
#     Longitude  Latitude                                            Pincode
# 0     77.5944   12.9914                                             560001
# 1     77.5937   12.9719                                             560002
# 2     77.5648   13.0097                                             560003
# 3     76.0303   13.5207                                             560004
# 4     74.4891   14.0998                                             560004
# 5     77.5714   12.9417                                             560004
# 6     76.9627   13.2029                 560005,560006,560007,560008,560009
# 7     77.5491   12.9847                                             560010
# 8     76.2752   15.8266   560011,560012,560014,560015,560016,560018,560019
# 9     77.5474   13.0448                                             560013
# 10    73.7291   21.4504                                             560017
# ...

# %%
dataconcat13=pd.concat([datasetsecond,dataset3],axis=1)
dataconcat13=dataconcat13.drop(['longitude','latitude'],axis=1)
dataconcat13
# Out:
#     Longitude  Latitude                                            Pincode  \
# 0     77.5944   12.9914                                             560001
# 1     77.5937   12.9719                                             560002
# 2     77.5648   13.0097                                             560003
# 3     76.0303   13.5207                                             560004
# 4     74.4891   14.0998                                             560004
# 5     77.5714   12.9417                                             560004
# 6     76.9627   13.2029                 560005,560006,560007,560008,560009
# 7     77.5491   12.9847                                             560010
# 8     76.2752   15.8266   560011,560012,560014,560015,560016,560018,560019
# 9     77.5474   13.0448                                             560013
# 10    73.7291   21.4504                                             560017
# ...

# %%
dataconcat13=dataconcat13.applymap(lambda x: x if ',' not in str(x) else ','.join(sorted(set(y.strip() for y in(x.split(','))))))
dataconcat13
# Out:
#     Longitude  Latitude                                            Pincode  \
# 0     77.5944   12.9914                                             560001
# 1     77.5937   12.9719                                             560002
# 2     77.5648   13.0097                                             560003
# 3     76.0303   13.5207                                             560004
# 4     74.4891   14.0998                                             560004
# 5     77.5714   12.9417                                             560004
# 6     76.9627   13.2029                 560005,560006,560007,560008,560009
# 7     77.5491   12.9847                                             560010
# 8     76.2752   15.8266   560011,560012,560014,560015,560016,560018,560019
# 9     77.5474   13.0448                                             560013
# 10    73.7291   21.4504                                             560017
# ...

# %%
dataconcat13=dataconcat13.drop(['Longitude','Latitude'], axis=1)
dataconcat13
# Out:
#                                               Pincode  Number of Food Outlets
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                       0
# 4                                              560004                       0
# 5                                              560004                      35
# 6                  560005,560006,560007,560008,560009                       0
# 7                                              560010                      37
# 8    560011,560012,560014,560015,560016,560018,560019                       0
# 9                                              560013                       9
# 10                                             560017                       0
# ...

# %%
dataconcat13=dataconcat13.groupby(['Pincode'],sort=False).agg(sum)
dataconcat13=dataconcat13.reset_index(drop=False, inplace=False)
dataconcat13=dataconcat13.applymap(lambda x: x if ',' not in str(x) else ','.join(sorted(set(y.strip() for y in(x.split(','))))))
dataconcat13
# Out:
#                                               Pincode  Number of Food Outlets
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %%
dataconcat13=dataconcat13[dataconcat13.Pincode !='560085,560092']
dataconcat13=dataconcat13.set_value(42,'Number of Food Outlets',74)
dataconcat13=dataconcat13.set_value(46,'Number of Food Outlets',53)
dataconcat13
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
#                                               Pincode  Number of Food Outlets
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# ...

# %%
dataconcat14=dataconcat13.replace({'560091,560092': 560091})
dataconcat14=dataconcat14.reset_index(drop=True,inplace=False)
dataconcat14
# Out:
#                                               Pincode  Number of Food Outlets
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %% [markdown]
# Obtaining the areas in Bangalore according to Longitude,Latitude and Pincode

# %%
dataf3['Pincode']=dataf3['Pincode'].astype(str)

# %%
dataf4=dataf3.groupby(['Longitude', 'Latitude'],sort=False).agg(','.join)
dataf5=dataf4.reset_index(drop=False, inplace=False)
dataf5
# Out:
#                          Longitude                        Latitude  \
# 0                          77.5944                         12.9914
# 1                          77.5937                         12.9719
# 2                          77.5648                         13.0097
# 3          74.4891,76.0303,77.5714         12.9417,13.5207,14.0998
# 4                          76.9627                         13.2029
# 5                          77.5491                         12.9847
# 6                          76.2752                         15.8266
# 7                          77.5474                         13.0448
# 8                          73.7291                         21.4504
# 9                          77.5789                         12.9879
# 10                         77.5625                         12.9879
# 11                         77.4484                           13.11
# 12                         77.5489                          12.975
# ...

# %%
dataf6=dataf5.applymap(lambda x: x if ',' not in str(x) else ','.join(sorted(set(y.strip() for y in(x.split(','))))))
dataf6
# Out:
#                          Longitude                        Latitude  \
# 0                          77.5944                         12.9914
# 1                          77.5937                         12.9719
# 2                          77.5648                         13.0097
# 3          74.4891,76.0303,77.5714         12.9417,13.5207,14.0998
# 4                          76.9627                         13.2029
# 5                          77.5491                         12.9847
# 6                          76.2752                         15.8266
# 7                          77.5474                         13.0448
# 8                          73.7291                         21.4504
# 9                          77.5789                         12.9879
# 10                         77.5625                         12.9879
# 11                         77.4484                           13.11
# 12                         77.5489                          12.975
# ...

# %%
datafinal=pd.concat([dataconcat14,dataconcat12grouped],axis=1)
dataArea=dataf6['Area']
datafinal1=pd.concat([datafinal,dataArea],axis=1)
datafinal1
# Out:
#                                               Pincode  Number of Food Outlets  \
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %% [markdown]
# 3.2 Applying the K-means Clustering algorithm on the final dataset- datafinal1

# %% [markdown]
# Importing libraries

# %%
import numpy as np
from sklearn.cluster import KMeans

# %% [markdown]
# Renaming employee number columns in datafinal1 for easier computation.

# %%
datafinal1=datafinal1.rename(columns={'E.no 1-50': 'One'})
datafinal1=datafinal1.rename(columns={'E.no 51-100': 'Two'})
datafinal1=datafinal1.rename(columns={'E.no 101-250': 'Three'})
datafinal1=datafinal1.rename(columns={'E.no 251-500': 'Four'})
datafinal1=datafinal1.rename(columns={'E.no 501-1000': 'Five'})
datafinal1=datafinal1.rename(columns={'E.no 1001-2500': 'Six'})
datafinal1=datafinal1.rename(columns={'E.no 2501-5000': 'Seven'})
datafinal1
# Out:
#                                               Pincode  Number of Food Outlets  \
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %%
datafinal1=datafinal1.rename(columns={'E.no 5001 & above': 'Eight'})
datafinal1
# Out:
#                                               Pincode  Number of Food Outlets  \
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %% [markdown]
# Removing Longitudes and their corresponding Latitudes from Coulmns :'Longitude','Latitude'of datafinal1 for easier compuation of clustering algorithm.
# note:Both, number of companies and food outlets in various areas(with pincodes) of Bangalore (having more than 1 longitude and latitude) remain unaffected.

# %%
datafinal1=datafinal1.replace({'74.4891,76.0303,77.5714': 74.4891})
datafinal1=datafinal1.replace({'12.9417,13.5207,14.0998': 12.9417})
datafinal1=datafinal1.replace({'77.5523,77.5726,77.593': 77.5523})
datafinal1=datafinal1.replace({'12.9299,12.9955,13.0611': 12.9299})
datafinal1=datafinal1.replace({'77.5617,77.5663,77.5709': 77.5617})
datafinal1=datafinal1.replace({'12.902,12.9038,12.9057': 12.902})
datafinal1=datafinal1.replace({'77.5732,77.5831,77.593': 77.5732})
datafinal1=datafinal1.replace({'77.5896,77.6011': 77.5896})
datafinal1=datafinal1.replace({'12.8608,12.9023': 12.8608})
datafinal1
# Out:
#                                               Pincode  Number of Food Outlets  \
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %%
datafinal1=datafinal1.replace({'77.5963,78.0988,78.6014': 77.5963})
datafinal1=datafinal1.replace({'11.5941,12.3477,13.1013': 11.5941})
datafinal1=datafinal1.replace({'77.5978,77.6001': 77.5978})
datafinal1=datafinal1.replace({'12.8939,12.9106': 12.8939})
datafinal1=datafinal1.replace({'13.0583,13.0597,13.0611':13.0583})
datafinal1
# Out:
#                                               Pincode  Number of Food Outlets  \
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %%
datafinal1=datafinal1.replace({'77.6209,77.626,77.6279,77.6299': 77.6209})
datafinal1=datafinal1.replace({'12.8706,12.8931,12.8949,12.924': 12.8706})
datafinal1=datafinal1.replace({'77.6804,77.6809': 77.6804})
datafinal1=datafinal1.replace({'12.8263,12.8311': 12.8263})
datafinal1=datafinal1.replace({'77.6869,77.7164': 77.6869})
datafinal1=datafinal1.replace({'12.9923,12.9944': 12.9923})
datafinal1
# Out:
#                                               Pincode  Number of Food Outlets  \
# 0                                              560001                      31
# 1                                              560002                      49
# 2                                              560003                      47
# 3                                              560004                      35
# 4                  560005,560006,560007,560008,560009                       0
# 5                                              560010                      37
# 6    560011,560012,560014,560015,560016,560018,560019                       0
# 7                                              560013                       9
# 8                                              560017                       0
# 9                                              560020                      42
# 10                                             560021                      44
# ...

# %%
datafinal1['Longitude']=datafinal1['Longitude'].astype(float)
datafinal1['Latitude']=datafinal1['Latitude'].astype(float)

# %%
datafinal1['Number of Food Outlets']=datafinal1['Number of Food Outlets'].astype(int)

# %%
k=13
restaurant_clustering =datafinal1.drop(['Pincode','Number of Food Outlets','Area','One','Two','Three','Four','Five','Six','Seven','Eight'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(restaurant_clustering)
kmeans.labels_
datafinal1.insert(0, 'Clusters', kmeans.labels_)
data
datafinal1
# Out:
#     Clusters                                            Pincode  \
# 0          1                                             560001
# 1          2                                             560002
# 2          3                                             560003
# 3          4                                             560004
# 4          8                 560005,560006,560007,560008,560009
# 5          5                                             560010
# 6          5   560011,560012,560014,560015,560016,560018,560019
# 7         10                                             560013
# 8          7                                             560017
# 9          9                                             560020
# 10         9                                             560021
# 11        12                               560022,560024,560026
# 12        12                                             560023
# 13        10                                             560025
# ...

# %%
C0=datafinal1.loc[datafinal1['Clusters'] == 0, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C0
# Out:
#           Pincode  Number of Food Outlets  Longitude  Latitude  One  Two  \
# 42  560086,560087                      50    77.6226   13.0360    9   11
# 44         560091                      19    77.6374   13.0096   20    5
# 45         560092                      53    77.6391   12.9617   51   31
# 46         560096                      22    77.6487   13.0158  100   45
# 48         560098                       5    77.6765   12.9255   22   28
# 50         560100                      44    77.6869   12.9923   31   32
# 52         560103                      33    77.7473   12.9716   66   31
#
#     Three  Four  Five  Six  Seven  Eight  \
# 42     14     9     4    5      3      1
# 44      2     0     0    0      0      0
# 45     21     8     5    2      4      2
# 46     38    12     2    1      0      1
# 48     27    21     7    2      5      7
# 50     33    10    12    6      2      3
# 52     52    31    14    5      3      2
#
# ...

# %%
print('1-50:',C0['One'].sum())
print('51-100:',C0['Two'].sum())
print('101-250:',C0['Three'].sum())
print('251-500:',C0['Four'].sum())
print('501-1000:',C0['Five'].sum())
print('1001-2500:',C0['Six'].sum())
print('2500-5000:',C0['Seven'].sum())
print('5000 & above:',C0['Eight'].sum())
print('Number of Food Outlets:',C0['Number of Food Outlets'].sum())
# Out:
# 1-50: 299
# 51-100: 183
# 101-250: 187
# 251-500: 91
# 501-1000: 44
# 1001-2500: 21
# 2500-5000: 17
# 5000 & above: 16
# Number of Food Outlets: 226

# %%
C1=datafinal1.loc[datafinal1['Clusters'] == 1, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C1
# Out:
#   Pincode  Number of Food Outlets  Longitude  Latitude  One  Two  Three  Four  \
# 0  560001                      31    73.7291   21.4504   36   15     16     7
#
#    Five  Six  Seven  Eight                                               Area
# 0     0    3      0      1  Bangalore Bazaar,Bangalore G.P.O.,CMM Court Co...

# %%
print('1-50:',C1['One'].sum())
print('51-100:',C1['Two'].sum())
print('101-250:',C1['Three'].sum())
print('251-500:',C1['Four'].sum())
print('501-1000:',C1['Five'].sum())
print('1001-2500:',C1['Six'].sum())
print('2500-5000:',C1['Seven'].sum())
print('5000 & above:',C1['Eight'].sum())
print('Number of Food Outlets:',C1['Number of Food Outlets'].sum())
# Out:
# 1-50: 36
# 51-100: 15
# 101-250: 16
# 251-500: 7
# 501-1000: 0
# 1001-2500: 3
# 2500-5000: 0
# 5000 & above: 1
# Number of Food Outlets: 31

# %%
C2=datafinal1.loc[datafinal1['Clusters'] == 2, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C2
# Out:
#   Pincode  Number of Food Outlets  Longitude  Latitude  One  Two  Three  Four  \
# 1  560002                      49    74.4891   12.9417   53   28     27    10
#
#    Five  Six  Seven  Eight                                               Area
# 1     0    2      1      1  Bangalore City,Bangalore Corporation Building,...

# %%
print('1-50:',C2['One'].sum())
print('51-100:',C2['Two'].sum())
print('101-250:',C2['Three'].sum())
print('251-500:',C2['Four'].sum())
print('501-1000:',C2['Five'].sum())
print('1001-2500:',C2['Six'].sum())
print('2500-5000:',C2['Seven'].sum())
print('5000 & above:',C2['Eight'].sum())
print('Number of Food Outlets:',C2['Number of Food Outlets'].sum())
# Out:
# 1-50: 53
# 51-100: 28
# 101-250: 27
# 251-500: 10
# 501-1000: 0
# 1001-2500: 2
# 2500-5000: 1
# 5000 & above: 1
# Number of Food Outlets: 49

# %%
C3=datafinal1.loc[datafinal1['Clusters'] == 3, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C3
# Out:
#   Pincode  Number of Food Outlets  Longitude  Latitude  One  Two  Three  Four  \
# 2  560003                      47    76.2752   15.8266  112   63     41    18
#
#    Five  Six  Seven  Eight                                               Area
# 2     5    2      0      2  Malleswaram,Palace Guttahalli,Swimming Pool Ex...

# %%
print('1-50:',C3['One'].sum())
print('51-100:',C3['Two'].sum())
print('101-250:',C3['Three'].sum())
print('251-500:',C3['Four'].sum())
print('501-1000:',C3['Five'].sum())
print('1001-2500:',C3['Six'].sum())
print('2500-5000:',C3['Seven'].sum())
print('5000 & above:',C3['Eight'].sum())
print('Number of Food Outlets:',C3['Number of Food Outlets'].sum())
# Out:
# 1-50: 112
# 51-100: 63
# 101-250: 41
# 251-500: 18
# 501-1000: 5
# 1001-2500: 2
# 2500-5000: 0
# 5000 & above: 2
# Number of Food Outlets: 47

# %%
C4=datafinal1.loc[datafinal1['Clusters'] == 4, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C4
# Out:
#   Pincode  Number of Food Outlets  Longitude  Latitude  One  Two  Three  Four  \
# 3  560004                      35    76.5761   10.8368   16    8      6     2
#
#    Five  Six  Seven  Eight                                               Area
# 3     1    1      0      0  Basavanagudi,Mavalli,Pampamahakavi Road,Thyaga...

# %%
print('1-50:',C4['One'].sum())
print('51-100:',C4['Two'].sum())
print('101-250:',C4['Three'].sum())
print('251-500:',C4['Four'].sum())
print('501-1000:',C4['Five'].sum())
print('1001-2500:',C4['Six'].sum())
print('2500-5000:',C4['Seven'].sum())
print('5000 & above:',C4['Eight'].sum())
print('Number of Food Outlets:',C4['Number of Food Outlets'].sum())
# Out:
# 1-50: 16
# 51-100: 8
# 101-250: 6
# 251-500: 2
# 501-1000: 1
# 1001-2500: 1
# 2500-5000: 0
# 5000 & above: 0
# Number of Food Outlets: 35

# %%
C5=datafinal1.loc[datafinal1['Clusters'] == 5, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C5
# Out:
#                                             Pincode  Number of Food Outlets  \
# 5                                            560010                      37
# 6  560011,560012,560014,560015,560016,560018,560019                       0
#
#    Longitude  Latitude  One  Two  Three  Four  Five  Six  Seven  Eight  \
# 5    76.9627   13.2029  169   85     59    19     4    3      1      1
# 6    77.0942   13.1791  104   64     48    12     5    0      0      1
#
#                                                 Area
# 5  Industrial Estate (Bangalore),Rajajinagar,Raja...
# 6  Chamrajpet (Bangalore),Doorvaninagar,Gaviopura...

# %%
print('1-50:',C5['One'].sum())
print('51-100:',C5['Two'].sum())
print('101-250:',C5['Three'].sum())
print('251-500:',C5['Four'].sum())
print('501-1000:',C5['Five'].sum())
print('1001-2500:',C5['Six'].sum())
print('2500-5000:',C5['Seven'].sum())
print('5000 & above:',C5['Eight'].sum())
print('Number of Food Outlets:',C5['Number of Food Outlets'].sum())
# Out:
# 1-50: 273
# 51-100: 149
# 101-250: 107
# 251-500: 31
# 501-1000: 9
# 1001-2500: 3
# 2500-5000: 1
# 5000 & above: 2
# Number of Food Outlets: 37

# %%
C6=datafinal1.loc[datafinal1['Clusters'] == 6, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C6
# Out:
#    Pincode  Number of Food Outlets  Longitude  Latitude  One  Two  Three  \
# 33  560071                      50    77.5963   11.5941   43   20     25
#
#     Four  Five  Six  Seven  Eight    Area
# 33    10     1    2      1      0  Domlur

# %%
print('1-50:',C6['One'].sum())
print('51-100:',C6['Two'].sum())
print('101-250:',C6['Three'].sum())
print('251-500:',C6['Four'].sum())
print('501-1000:',C6['Five'].sum())
print('1001-2500:',C6['Six'].sum())
print('2500-5000:',C6['Seven'].sum())
print('5000 & above:',C6['Eight'].sum())
print('Number of Food Outlets:',C6['Number of Food Outlets'].sum())
# Out:
# 1-50: 43
# 51-100: 20
# 101-250: 25
# 251-500: 10
# 501-1000: 1
# 1001-2500: 2
# 2500-5000: 1
# 5000 & above: 0
# Number of Food Outlets: 50

# %%
C7=datafinal1.loc[datafinal1['Clusters'] == 7, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C7
# Out:
#                                       Pincode  Number of Food Outlets  \
# 8                                      560017                       0
# 16                                     560030                      50
# 19                       560040,560042,560047                       0
# 25                                     560049                       0
# 28         560061,560062,560063,560065,560067                       0
# 29                                     560064                      11
# 32  560070,560073,560074,560075,560077,560079                      50
# 35                                     560076                      98
# 36                                     560078                      57
# 37                                     560080                      37
# 39                                     560083                      62
# 40                                     560084                      32
# ...

# %%
print('1-50:',C7['One'].sum())
print('51-100:',C7['Two'].sum())
print('101-250:',C7['Three'].sum())
print('251-500:',C7['Four'].sum())
print('501-1000:',C7['Five'].sum())
print('1001-2500:',C7['Six'].sum())
print('2500-5000:',C7['Seven'].sum())
print('5000 & above:',C7['Eight'].sum())
print('Number of Food Outlets:',C7['Number of Food Outlets'].sum())
# Out:
# 1-50: 902
# 51-100: 484
# 101-250: 407
# 251-500: 140
# 501-1000: 69
# 1001-2500: 35
# 2500-5000: 15
# 5000 & above: 23
# Number of Food Outlets: 504

# %%
C8=datafinal1.loc[datafinal1['Clusters'] == 8, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C8
# Out:
#                               Pincode  Number of Food Outlets  Longitude  \
# 4  560005,560006,560007,560008,560009                       0    76.8024
#
#    Latitude  One  Two  Three  Four  Five  Six  Seven  Eight  \
# 4   13.7952   28   15     17     6     7    4      3      2
#
#                                                 Area
# 4  Agram,Air Force Hospital,Bangalore Dist Office...

# %%
print('1-50:',C8['One'].sum())
print('51-100:',C8['Two'].sum())
print('101-250:',C8['Three'].sum())
print('251-500:',C8['Four'].sum())
print('501-1000:',C8['Five'].sum())
print('1001-2500:',C8['Six'].sum())
print('2500-5000:',C8['Seven'].sum())
print('5000 & above:',C8['Eight'].sum())
print('Number of Food Outlets:',C8['Number of Food Outlets'].sum())
# Out:
# 1-50: 28
# 51-100: 15
# 101-250: 17
# 251-500: 6
# 501-1000: 7
# 1001-2500: 4
# 2500-5000: 3
# 5000 & above: 2
# Number of Food Outlets: 0

# %%
C9=datafinal1.loc[datafinal1['Clusters'] == 9, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C9
# Out:
#    Pincode  Number of Food Outlets  Longitude  Latitude  One  Two  Three  \
# 9   560020                      42    77.4920   12.6859   88   39     42
# 10  560021                      44    77.5053   12.7717   16   15     11
#
#     Four  Five  Six  Seven  Eight                       Area
# 9      9     5    5      2      0              Seshadripuram
# 10     4     0    0      0      0  Gayathrinagar,Srirampuram

# %%
print('1-50:',C9['One'].sum())
print('51-100:',C9['Two'].sum())
print('101-250:',C9['Three'].sum())
print('251-500:',C9['Four'].sum())
print('501-1000:',C9['Five'].sum())
print('1001-2500:',C9['Six'].sum())
print('2500-5000:',C9['Seven'].sum())
print('5000 & above:',C9['Eight'].sum())
print('Number of Food Outlets:',C9['Number of Food Outlets'].sum())
# Out:
# 1-50: 104
# 51-100: 54
# 101-250: 53
# 251-500: 13
# 501-1000: 5
# 1001-2500: 5
# 2500-5000: 2
# 5000 & above: 0
# Number of Food Outlets: 86

# %%
C10=datafinal1.loc[datafinal1['Clusters'] == 10, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C10
# Out:
#                                              Pincode  Number of Food Outlets  \
# 7                                             560013                       9
# 13                                            560025                      48
# 17  560032,560033,560035,560036,560037,560038,560039                      50
# 22                                            560045                      20
# 23                                            560046                      37
# 27                                            560060                       8
#
#     Longitude  Latitude  One  Two  Three  Four  Five  Six  Seven  Eight  \
# 7     77.4484   13.1100   67   49     34    18     2    7      1      1
# 13    77.5474   13.0448    7    5      7     1     0    0      0      1
# 17    77.5566   13.0814   16    3      5     1     1    0      0      0
# 22    77.5732   13.0583   38    8     15     1     0    0      0      0
# ...

# %%
print('1-50:',C10['One'].sum())
print('51-100:',C10['Two'].sum())
print('101-250:',C10['Three'].sum())
print('251-500:',C10['Four'].sum())
print('501-1000:',C10['Five'].sum())
print('1001-2500:',C10['Six'].sum())
print('2500-5000:',C10['Seven'].sum())
print('5000 & above:',C10['Eight'].sum())
print('Number of Food Outlets:',C10['Number of Food Outlets'].sum())
# Out:
# 1-50: 165
# 51-100: 85
# 101-250: 75
# 251-500: 26
# 501-1000: 4
# 1001-2500: 8
# 2500-5000: 1
# 5000 & above: 3
# Number of Food Outlets: 172

# %%
C11=datafinal1.loc[datafinal1['Clusters'] == 11, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C11
# Out:
#                         Pincode  Number of Food Outlets  Longitude  Latitude  \
# 47                       560097                       7    77.6727   12.8458
# 49                       560099                      28    77.6804   12.8263
# 51  560102,560104,560109,560110                       0    77.7432   12.7690
#
#     One  Two  Three  Four  Five  Six  Seven  Eight  \
# 47   48   38     35    23     6    6      2      5
# 49   24   22     40    11     7    3      2      0
# 51   52   29     19    14     6    1      1      0
#
#                                                  Area
# 47                    Chikkabettahalli,Vidyaranyapura
# 49  Bommasandra Industrial Estate,Hebbagodi,Muthan...
# 51  HSR Layout,Hampinagar,Thalaghattapura,Ullalu U...

# %%
print('1-50:',C11['One'].sum())
print('51-100:',C11['Two'].sum())
print('101-250:',C11['Three'].sum())
print('251-500:',C11['Four'].sum())
print('501-1000:',C11['Five'].sum())
print('1001-2500:',C11['Six'].sum())
print('2500-5000:',C11['Seven'].sum())
print('5000 & above:',C11['Eight'].sum())
print('Number of Food Outlets:',C11['Number of Food Outlets'].sum())
# Out:
# 1-50: 124
# 51-100: 89
# 101-250: 94
# 251-500: 48
# 501-1000: 19
# 1001-2500: 10
# 2500-5000: 5
# 5000 & above: 5
# Number of Food Outlets: 35

# %%
C12=datafinal1.loc[datafinal1['Clusters'] == 12, datafinal1.columns[[1] + list(range(2, datafinal1.shape[1]))]]
C12
# Out:
#                                               Pincode  Number of Food Outlets  \
# 11                               560022,560024,560026                       0
# 12                                             560023                      32
# 14                                             560027                      31
# 15                                             560029                       0
# 18                                             560034                      50
# 20                                             560041                      50
# 21                                             560043                      28
# 24                                             560048                      41
# 26  560050,560051,560053,560054,560055,560056,5600...                      40
# 30                                             560066                      22
# 31                                             560068                      95
# ...

# %%
print('1-50:',C12['One'].sum())
print('51-100:',C12['Two'].sum())
print('101-250:',C12['Three'].sum())
print('251-500:',C12['Four'].sum())
print('501-1000:',C12['Five'].sum())
print('1001-2500:',C12['Six'].sum())
print('2500-5000:',C12['Seven'].sum())
print('5000 & above:',C12['Eight'].sum())
print('Number of Food Outlets:',C12['Number of Food Outlets'].sum())
# Out:
# 1-50: 759
# 51-100: 401
# 101-250: 334
# 251-500: 147
# 501-1000: 59
# 1001-2500: 26
# 2500-5000: 15
# 5000 & above: 14
# Number of Food Outlets: 398

# %%
L0=C0.One.sum(),C0.Two.sum(),C0.Three.sum(),C0.Four.sum(),C0.Five.sum(),C0.Six.sum(),C0.Seven.sum(),C0.Eight.sum(),C0['Number of Food Outlets'].sum()
L1=C1.One.sum(),C1.Two.sum(),C1.Three.sum(),C1.Four.sum(),C1.Five.sum(),C1.Six.sum(),C1.Seven.sum(),C1.Eight.sum(),C1['Number of Food Outlets'].sum()
L2=C2.One.sum(),C2.Two.sum(),C2.Three.sum(),C2.Four.sum(),C2.Five.sum(),C2.Six.sum(),C2.Seven.sum(),C2.Eight.sum(),C2['Number of Food Outlets'].sum()
L3=C3.One.sum(),C3.Two.sum(),C3.Three.sum(),C3.Four.sum(),C3.Five.sum(),C3.Six.sum(),C3.Seven.sum(),C3.Eight.sum(),C3['Number of Food Outlets'].sum()
L4=C4.One.sum(),C4.Two.sum(),C4.Three.sum(),C4.Four.sum(),C4.Five.sum(),C4.Six.sum(),C4.Seven.sum(),C4.Eight.sum(),C4['Number of Food Outlets'].sum()
L5=C5.One.sum(),C5.Two.sum(),C5.Three.sum(),C5.Four.sum(),C5.Five.sum(),C5.Six.sum(),C5.Seven.sum(),C5.Eight.sum(),C5['Number of Food Outlets'].sum()
L6=C6.One.sum(),C6.Two.sum(),C6.Three.sum(),C6.Four.sum(),C6.Five.sum(),C6.Six.sum(),C6.Seven.sum(),C6.Eight.sum(),C6['Number of Food Outlets'].sum()
L7=C7.One.sum(),C7.Two.sum(),C7.Three.sum(),C7.Four.sum(),C7.Five.sum(),C7.Six.sum(),C7.Seven.sum(),C7.Eight.sum(),C7['Number of Food Outlets'].sum()
L8=C8.One.sum(),C8.Two.sum(),C8.Three.sum(),C8.Four.sum(),C8.Five.sum(),C8.Six.sum(),C8.Seven.sum(),C8.Eight.sum(),C8['Number of Food Outlets'].sum()
L9=C9.One.sum(),C9.Two.sum(),C9.Three.sum(),C9.Four.sum(),C9.Five.sum(),C9.Six.sum(),C9.Seven.sum(),C9.Eight.sum(),C1['Number of Food Outlets'].sum()
L10=C10.One.sum(),C10.Two.sum(),C10.Three.sum(),C10.Four.sum(),C10.Five.sum(),C10.Six.sum(),C10.Seven.sum(),C10.Eight.sum(),C10['Number of Food Outlets'].sum()
L11=C11.One.sum(),C11.Two.sum(),C11.Three.sum(),C11.Four.sum(),C11.Five.sum(),C11.Six.sum(),C11.Seven.sum(),C11.Eight.sum(),C11['Number of Food Outlets'].sum()
L12=C12.One.sum(),C12.Two.sum(),C12.Three.sum(),C12.Four.sum(),C12.Five.sum(),C12.Six.sum(),C12.Seven.sum(),C12.Eight.sum(),C12['Number of Food Outlets'].sum()
LF=pd.DataFrame([L0,L1,L2,L3,L4,L5,L6,L7,L8,L9,L10,L11,L12])
LF
# Out:
#       0    1    2    3   4   5   6   7    8
# 0   299  183  187   91  44  21  17  16  226
# 1    36   15   16    7   0   3   0   1   31
# 2    53   28   27   10   0   2   1   1   49
# 3   112   63   41   18   5   2   0   2   47
# 4    16    8    6    2   1   1   0   0   35
# 5   273  149  107   31   9   3   1   2   37
# 6    43   20   25   10   1   2   1   0   50
# 7   902  484  407  140  69  35  15  23  504
# 8    28   15   17    6   7   4   3   2    0
# 9   104   54   53   13   5   5   2   0   31
# 10  165   85   75   26   4   8   1   3  172
# 11  124   89   94   48  19  10   5   5   35
# 12  759  401  334  147  59  26  15  14  398

# %%
LF.columns=['1-50','51-100','101-250','251-500','501-1000','1001-2500','2501-5000','5000 & above','Number of Food Outlets']
LF.index=['C0','C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12']
LF
# Out:
#      1-50  51-100  101-250  251-500  501-1000  1001-2500  2501-5000  \
# C0    299     183      187       91        44         21         17
# C1     36      15       16        7         0          3          0
# C2     53      28       27       10         0          2          1
# C3    112      63       41       18         5          2          0
# C4     16       8        6        2         1          1          0
# C5    273     149      107       31         9          3          1
# C6     43      20       25       10         1          2          1
# C7    902     484      407      140        69         35         15
# C8     28      15       17        6         7          4          3
# C9    104      54       53       13         5          5          2
# C10   165      85       75       26         4          8          1
# C11   124      89       94       48        19         10          5
# C12   759     401      334      147        59         26         15
#
# ...

# %% [markdown]
# 4.Visualizing the clusters

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
# ...

# %%
import folium

# %%
map_clusters = folium.Map(location=[12.9716,77.5946],zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, area, cluster in zip(datafinal1['Latitude'], datafinal1['Longitude'], datafinal1['Area'], datafinal1['Clusters']):
    label = folium.Popup(' Clusters ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 4. Discussion:From the resultant dataframe consisting of 13 clusters (generated using K-means clustering algorithm), cluster5 (C5-marked with a red square) was identified as a potential cluster corresponding to Areas in Bangalore (Rajajinagar, Industrial Estate (Bangalore),Rajajinagar IVth Block, Jayangar III Block, Madhavan Park, Science Institute, Jalahalli East, Jalahalli West, Krishnarajapuram R S, Doorvaninagar, Ramamurthy Nagar, Chamrajpet (Bangalore), Gaviopuram Extension having significant number of companies with considerable employee sizes and low number of food outlets. The suggested areas possess the respective pincodes: 560010, 560010, 560011, 560011, 560012, 560014, 560015, 560016, 560016, 560016, 560018, 560019.These are potential areas where a customer can open a restaurant.
#
# 5. Conclusion: Geographical location data, pincodes, employee sizes and company data, location data of food outlets by Foursquare and K-means clustering algorithm were used to help a customer identify potential areas/neighborhoods in Bangalore to open a restaurant.
